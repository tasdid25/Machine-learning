# %% [markdown]
# <a href="https://colab.research.google.com/github/tasdid25/Machine-learning/blob/main/Binary_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2 style="color:green" align="center">Predicting if a person would buy life insurnace based on his age using binary logistic regression</h2>

# %% [markdown]
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't).

# %%
import pandas as pd
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
type(df.bought_insurance)
# Out:
# pandas.core.series.Series

# %%
type(df.age)
# Out:
# pandas.core.series.Series

# %%
type(df[['age']])
# Out:
# pandas.core.frame.DataFrame

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size=0.8, random_state=42)

# %%
X_train
# Out:
#     age
# 16   25
# 17   58
# 12   27
# 24   50
# 1    25
# 4    46
# 5    56
# 2    47
# 15   55
# 22   40
# 3    52
# 25   54
# 23   45
# 18   19
# 26   23
# 20   21
# 7    60
# 10   18
# 14   49
# 19   18
# 6    55

# %%
X_test
# Out:
#     age
# 8    62
# 13   29
# 9    61
# 21   26
# 0    22
# 11   28

# %%
y_train
# Out:
# 16    1
# 17    1
# 12    0
# 24    1
# 1     0
# 4     1
# 5     1
# 2     1
# 15    1
# 22    1
# 3     0
# 25    1
# 23    1
# 18    0
# 26    0
# 20    0
# 7     1
# 10    0
# 14    1
# 19    0
# 6     0
# Name: bought_insurance, dtype: int64

# %%
y_test
# Out:
# 8     1
# 13    0
# 9     1
# 21    0
# 0     0
# 11    0
# Name: bought_insurance, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_test
# Out:
# 8     1
# 13    0
# 9     1
# 21    0
# 0     0
# 11    0
# Name: bought_insurance, dtype: int64

# %%
y_predicted = model.predict(X_test)

# %%
y_predicted
# Out:
# array([1, 0, 1, 0, 0, 0])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.predict([[90]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])

# %% [markdown]
# **model.coef_ indicates value of m in y=m*x + b equation**

# %%
model.coef_
# Out:
# array([[0.11307708]])

# %% [markdown]
# **model.intercept_ indicates value of b in y=m*x + b equation**

# %%
model.intercept_
# Out:
# array([-4.15311919])

# %%
model.predict([[20]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %% [markdown]
# **Lets defined sigmoid function now and do the math with hand**

# %%
import math
def sigmoid(z):
  return 1 / (1 + math.exp(-z))

# %%
def prediction_function(age):
    y = 0.15568883 * age -6.40777392
    x = sigmoid(y)
    #print(y)
    if x<0.5:
        return 0
    else:
        return 1

# %%
prediction_function(50)
# Out:
# 1

# %% [markdown]
# **0.485 is less than 0.5 which means person with 35 age will *not* buy insurance**

# %%
age = 40
prediction_function(age)

#model.predict([[age]])
# Out:
# 0

# %% [markdown]
# **0.485 is more than 0.5 which means person with 43 will buy the insurance**

# %% [markdown]
# <h2 style="color:purple">Exercise</h2>
#
# Download employee retention dataset from here: https://www.kaggle.com/giripujar/hr-analytics.
# 1. Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)
# 2. Plot bar charts showing impact of employee salaries on retention
# 3. Plot bar charts showing corelation between department and employee retention
# 4. Now build logistic regression model using variables that were narrowed down in step 1
# 5. Measure the accuracy of the model
