# %% [markdown]
# # Pandas Built-in Data Visualization
#
# Hi Guys,<br>
# Welcome to [pandas for Data Visualization](https://pandas.pydata.org/pandas-docs/stable/visualization.html) now. In the Data Analysis section, we have explored the power of pandas for data analysis. Let's talk about pandas built-in data visualization capabilities. We can create decent looking plots using pandas. This is actually built on matplotlib and embedded into pandas for quick use. <br>
#
# Let's take a look!
# ### Histograms
# ### Area plot
# ### Bar plots
# ### Line plots
# ### Scatter plots
# ### BoxPlots
# ### Pie Plot

# %%
# let's do some imports first
import numpy as np
import pandas as pd

# %% [markdown]
# Let's create some random datasets now! <br>
# df1 with date as index and df2 with sequential index.
#
# *Although, we can use seaborn built-in datasets as well. To make this lecture as a separate and independent, I am creating new data frames here to use.*

# %% [markdown]
# ### Generating `df1`

# %%
#We can use date_range function from pandas
# periods = 500, no of periods (days) to generate
dates = pd.date_range('1/1/2023', periods=500)
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                '2023-01-09', '2023-01-10',
#                ...
#                '2024-05-05', '2024-05-06', '2024-05-07', '2024-05-08',
#                '2024-05-09', '2024-05-10', '2024-05-11', '2024-05-12',
#                '2024-05-13', '2024-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
# Let's use numpy's randn for "standard normal" distribution
data1 = np.random.randn(500,3) #(500,3) to tell the shape we want
data1
# Out:
# array([[-1.4287509 ,  0.72342789,  0.94386976],
#        [ 0.00799261, -0.15646218,  0.54723276],
#        [-1.24812319, -0.6232784 , -1.52016797],
#        ...,
#        [-0.2083676 , -1.86822626,  0.48302081],
#        [ 0.96717041,  0.73124605,  1.2051859 ],
#        [-0.99312771, -0.14781247,  1.47750811]])

# %%
data1.shape
# Out:
# (500, 3)

# %%
# randn(1000,4) 1000 by 4 2D array
df1 = pd.DataFrame(data = data1, index=dates, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#                    A         B         C
# 2023-01-01 -1.428751  0.723428  0.943870
# 2023-01-02  0.007993 -0.156462  0.547233
# 2023-01-03 -1.248123 -0.623278 -1.520168
# 2023-01-04  0.661025 -0.462091 -1.230842
# 2023-01-05 -0.309077  0.682853 -0.107528
# ...              ...       ...       ...
# 2024-05-10  0.380367 -1.936480 -1.218576
# 2024-05-11 -0.328008 -0.505292  0.519828
# 2024-05-12 -0.208368 -1.868226  0.483021
# 2024-05-13  0.967170  0.731246  1.205186
# 2024-05-14 -0.993128 -0.147812  1.477508
#
# [500 rows x 3 columns]

# %% [markdown]
# Let's add col_D as a column to df1

# %%
# Let's generate a series using rand()
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#                    A         B         C         D
# 2023-01-01  0.053280 -1.896166  0.207674  0.253465
# 2023-01-02 -0.465358  1.169162  0.050235  0.471135
# 2023-01-03 -0.477426  0.188670  0.951886  0.357095
# 2023-01-04 -0.319289 -0.406713  0.693106  0.726506
# 2023-01-05  0.402530 -0.917820  1.093395  0.562615
# ...              ...       ...       ...       ...
# 2024-05-10 -0.038265  0.152041  1.017457  0.671602
# 2024-05-11 -0.846792  0.651745 -0.818357  0.341507
# 2024-05-12  0.050151 -0.260594  0.093713  0.320691
# 2024-05-13  1.547409  1.298616 -0.360054  0.895332
# 2024-05-14 -0.061265  0.057347 -0.590297  0.556341
#
# [500 rows x 4 columns]

# %% [markdown]
# ### Generating `df2`

# %%
# rand(20,3) 20 by 3 2D array
data2 = np.random.rand(20,3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data = data2, columns=col)

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.169021  0.459318  0.935637
# 1  0.269905  0.831456  0.962998
# 2  0.842566  0.725912  0.703619
# 3  0.272485  0.254912  0.760044
# 4  0.087150  0.002306  0.088621

# %% [markdown]
# Let's start with simple histogram plot, we can get the hist plot in two ways!
# * `DataFrame.hist()`
# * `DataFrame.plot(kind = 'hist')`
#
# Let's try both one-by-one first, later on, we will talk about style sheet and discuss the range of plotting options in details!

# %%
df1['A'].hist() #edgecolor='black'
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor='black', bins=50)
# Out:
# <Axes: >

# %%
# we can also plot using kind
df1['A'].plot(kind='hist',bins=30, edgecolor='black',figsize=(5,4))
# Out:
# <Axes: ylabel='Frequency'>

# %%
# For whole dataset
df1.plot(kind='hist',bins=30,figsize=(5,4))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets). We can use this to make our plots look a little nicer. These style sheets include `plot_bmh`,`plot_fivethirtyeight`,`plot_ggplot` and more. They basically create a set of style rules that our plots follow. Its good to use them because they make all our plots to have the same look and feel more professional. <br>
# Let's call the style first!

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
# Lets use another style "bmh"
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# we can use dark_background
plt.style.use('dark_background')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# another example
plt.style.use('fivethirtyeight')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.169021  0.459318  0.935637
# 1  0.269905  0.831456  0.962998
# 2  0.842566  0.725912  0.703619
# 3  0.272485  0.254912  0.760044
# 4  0.087150  0.002306  0.088621

# %%
plt.style.use('dark_background')

# %%
df2['X'].plot(kind='hist', bins=50, figsize=(5,4))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Plot Types
#
# There are several plot types built-in to pandas, most of them are statistical plots by nature:
#
# * `df.plot.area`
# * `df.plot.bar`
# * `df.plot.barh`
# * `df.plot.hist`
# * `df.plot.line`
# * `df.plot.scatter`
# * `df.plot.box`
# * `df.plot.pie`
#
# We can also just call `df.plot(kind='hist')` or replace that kind argument with any of the key terms shown in the list above (e.g. `'box','barh'`, etc..)<br>
# **Let's go through these plots one-by-one using our data frames `df1` and `df2`!**

# %% [markdown]
# ### Area plot

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.169021  0.459318  0.935637
# 1  0.269905  0.831456  0.962998
# 2  0.842566  0.725912  0.703619
# 3  0.272485  0.254912  0.760044
# 4  0.087150  0.002306  0.088621

# %%
df2['X'].plot(figsize=(5,4))
# Out:
# <Axes: >

# %%
df2.plot(figsize=(5,4))
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area',figsize=(5,4))
# Out:
# <Axes: >

# %%
df2.plot.area(figsize=(5,4))
# Out:
# <Axes: >

# %% [markdown]
# ### Bar plots

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.169021  0.459318  0.935637
# 1  0.269905  0.831456  0.962998
# 2  0.842566  0.725912  0.703619
# 3  0.272485  0.254912  0.760044
# 4  0.087150  0.002306  0.088621

# %%
df2['X'].plot.bar(figsize=(5,3))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(5,3))
# Out:
# <Axes: >

# %%
# Horizontal bars
df2.plot.barh(figsize=(5,4))
# Out:
# <Axes: >

# %%
df2

# %%
#plt.style.use('ggplot')
df2.plot.bar(stacked=True, figsize=(5,4))
# Out:
# <Axes: >

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2023-01-01 -1.428751  0.723428  0.943870  0.334480
# 2023-01-02  0.007993 -0.156462  0.547233  0.924247
# 2023-01-03 -1.248123 -0.623278 -1.520168  0.523254
# 2023-01-04  0.661025 -0.462091 -1.230842  0.790754
# 2023-01-05 -0.309077  0.682853 -0.107528  0.529933

# %%
df1.plot.scatter(x='A', y='B', figsize=(7,2))
#plt.show()
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.line(x='A', y='B',figsize=(7,2),lw=.5)
# Out:
# <Axes: xlabel='A'>

# %%
df1.plot.scatter(x='A', y='B', c='0.8', cmap='coolwarm', figsize=(7,2))
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py:1266: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# The keyword `c` may be given as the name of a column to provide colors for each point. `cmap` can be used to indicate colormap. <br>
# For all the colormaps, [click here](http://matplotlib.org/users/colormaps.html)

# %%
df1

# %%
df1.plot.scatter(x='A',y='B', c='D', cmap='coolwarm', figsize=(7,2))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=90,  figsize=(10,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D']*100, figsize=(10,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=df1['D']*100, c='D', cmap='coolwarm', figsize=(10,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A',y='B', gridsize=30, cmap='Oranges',  figsize=(10,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ### Line plots

# %%
gas = pd.read_csv('gas_prices.csv')
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %% [markdown]
# ### Using Pandas

# %%
gas['UK'].plot(figsize=(5,4))
# Out:
# <Axes: >

# %%
gas.plot(x='Year', y='UK',figsize=(5,4))
# Out:
# <Axes: xlabel='Year'>

# %%
gas.Year[::3].tolist() # [1990, 1993, 1996]
# Out:
# [1990, 1993, 1996, 1999, 2002, 2005, 2008]

# %%
gas.plot(x='Year', y='UK', xticks = gas.Year[::3].tolist(),figsize=(5,4))
# Out:
# <Axes: xlabel='Year'>

# %%
gas.plot(x='Year', y='UK', xticks=gas.Year[::3].tolist(),figsize=(5,3))
gas.plot(x='Year', y='USA', xticks=gas.Year[::3].tolist(),figsize=(5,3))
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### Using Pyplot

# %%
plt.style.use('dark_background')

# %%
plt.subplots(figsize=(5,4))
plt.plot(gas['Year'], gas['USA'], label='USA', marker='o', markeredgecolor="red")
plt.plot(gas['Year'], gas['Canada'], label='Canada', marker='o', markeredgecolor="red")
plt.xticks(gas.Year[::3].tolist())
plt.legend()
plt.show()

# %%
plt.figure(figsize=(5,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18, 'color':'g'})

plt.plot(gas.Year, gas.USA, 'b.-', label='USA')
plt.plot(gas.Year, gas['Canada'], 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='SKorea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Austrolia')

plt.xticks(gas.Year[::3].tolist()) #[1990, 1993, 1996, 1999, 2002, 2005, 2008]

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300, bbox_inches ='tight')

plt.show()

# %%
df1

# %% [markdown]
# ## BoxPlots
# To visualize the distribution of values within each column.

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.169021  0.459318  0.935637
# 1  0.269905  0.831456  0.962998
# 2  0.842566  0.725912  0.703619
# 3  0.272485  0.254912  0.760044
# 4  0.087150  0.002306  0.088621

# %%
df2['X'].max()
# Out:
# 0.9909601340793066

# %%
df2['X'].min()
# Out:
# 0.032407996763544444

# %%
df2['X'].quantile(0.25)
# Out:
# 0.16416409338999102

# %%
df2['X'].quantile(0.50)
# Out:
# 0.5971902036020589

# %%
df2['X'].quantile(0.75)
# Out:
# 0.7267539191349379

# %%
df2['X'].plot.box(figsize=(5,4))
# Out:
# <Axes: >

# %%
df2.plot.box()

# %%
df2.plot.box(vert=False)

# %% [markdown]
# ### Pie Plot
# We can create a pie plot with  `Series.plot.pie()` or `DataFrame.plot.pie()`. If your data includes any NaN, they will be automatically filled with 0. A ValueError will be raised if there are any negative values in your data.<br>
# Let's try pie plot with df2.<br>
#
# We need to specify a target column by the y argument. When y is specified, pie plot of selected column will be drawn.

# %%
df2.head()
# Out:
#           X         Y         Z
# 0  0.169021  0.459318  0.935637
# 1  0.269905  0.831456  0.962998
# 2  0.842566  0.725912  0.703619
# 3  0.272485  0.254912  0.760044
# 4  0.087150  0.002306  0.088621

# %%
# let's take use X column only
df2.plot.pie(y='X', figsize=(6, 6), autopct='%.2f %%')#,figsize=(12, 4),legend=False)
# Out:
# <Axes: ylabel='X'>

# %% [markdown]
# The plot above does not look nice, lets remove the legend and set the figure size!

# %%
fifa = pd.read_csv('fifa_data.csv')

fifa.head() #select * from fifa
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
fifa['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
def stripdata(x):
    if type(x)==str:
        return float(x[0:3])
    else:
        return x

# %%
# def stripdata(x):
#     if type(x)==str:
#         return float(x.split('l')[0])
#     else:
#         return x

# %%
# def stripdata(x):
#     if type(x)==str:
#         return int(x.strip('lbs'))
#     else:
#         return x

# %%
stripdata('159lbs')
# Out:
# 159.0

# %%
fifa['Weight'] = fifa['Weight'].apply(stripdata)

# %%
fifa['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
light = fifa[fifa.Weight < 125].count()[0]
light
# Out:
# <ipython-input-115-f7079c90fc36>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light = fifa[fifa.Weight < 125].count()[0]
# 41

# %%
light = fifa[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
weights
# Out:
# <ipython-input-116-f561c05b7060>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light = fifa[fifa.Weight < 125].count()[0]
# <ipython-input-116-f561c05b7060>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
# <ipython-input-116-f561c05b7060>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
# <ipython-input-116-f561c05b7060>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
# <ipython-input-116-f561c05b7060>:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   heavy = fifa[fifa.Weight >= 200].count()[0]
# [41, 2290, 10876, 4583, 369]

# %%
plt.figure(figsize=(6,6))

label = ['under 125', '125-150', '150-175', '175-200', 'over 200']

explodelist = [.4,.2,0,0,.4]

plt.pie(weights, labels=label, explode=explodelist, autopct='%.2f %%', pctdistance=0.8 )

#plt.pie(weights, labels=label, autopct='%.2f %%',  pctdistance=0.6)

plt.legend(title="Weight Range")

plt.show()

# %% [markdown]
# This was all about the data visualization using pandas. You can see that how convenient it is to use pandas data visualization capabilities while EDA. It balances ease of use with control over the figure. A lot of the plot calls also accept additional arguments of their parent matplotlib library call. <br>
#
# Let's move on to the exercises section now, where we will try to solve some tasks related to pandas data visualization. See you in the next lecture, Good Luck!
#
# # Great Job!
